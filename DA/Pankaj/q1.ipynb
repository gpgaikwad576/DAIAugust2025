# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\dai\Downloads\ds\world_population.csv")

# %%
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %% [markdown]
# ### null value analysis

# %%
#remove missing
df = df.dropna()
print(df.isna().sum().sum())
# Out:
# 0

# %% [markdown]
# ### Outlier analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]

    print("IQR OUTLIER DETECTION")
    print("=" * 30)
    print(f"Q1 (25th percentile): {Q1:.3f}")
    print(f"Q3 (75th percentile): {Q3:.3f}")
    print(f"IQR: {IQR:.3f}")
    print(f"Lower bound: {lower_bound:.3f}")
    print(f"Upper bound: {upper_bound:.3f}")
    print(f"Outliers found: {len(outliers)}")
    print(f"Outlier values: {outliers[column].tolist()}")

    return outliers, lower_bound, upper_bound

# %%
# Detect outliers
print("Outliers in Growth Rate: ")
print(detect_outliers_iqr(df[['Growth Rate']], 'Growth Rate'))
# Out:
# Outliers in Growth Rate:
# IQR OUTLIER DETECTION
# ...
# Q1 (25th percentile): 1.002
# Q3 (75th percentile): 1.017
# IQR: 0.015
# Lower bound: 0.979
# Upper bound: 1.040
# Outliers found: 3
# Outlier values: [1.0691, 1.0404, 0.912]
# (     Growth Rate
# 133       1.0691
# 164       1.0404
# 218       0.9120, np.float64(0.9790125000000002), np.float64(1.0397124999999998))

# %%
print("Outliers in Density: ")
print(detect_outliers_iqr(df[['Density (per km²)']], 'Density (per km²)'))
# Out:
# Outliers in Density:
# IQR OUTLIER DETECTION
# ...
# Q1 (25th percentile): 38.418
# Q3 (75th percentile): 238.933
# IQR: 200.515
# Lower bound: -262.355
# Upper bound: 539.706
# Outliers found: 22
# Outlier values: [591.3611, 1924.4876, 1160.035, 654.9651, 1188.5926, 5441.5, 811.5513, 6783.3922, 954.9828, 23172.2667, 1745.9567, 1687.6139, 636.9946, 871.9278, 18234.5, 603.2381, 844.063, 599.8302, 551.8033, 8416.4634, 1299.2647, 660.1662]
# (     Density (per km²)
# 10            591.3611
# 15           1924.4876
# 16           1160.0350
# 17            654.9651
# 22           1188.5926
# 76           5441.5000
# 83            811.5513
# 89           6783.3922
# 103           954.9828
# 119         23172.2667
# 123          1745.9567
# 125          1687.6139
# 129           636.9946
# 130           871.9278
# 134         18234.5000
# 142           603.2381
# 158           844.0630
# 176           599.8302
# 180           551.8033
# 187          8416.4634
# 188          1299.2647
# ...

# %% [markdown]
# ### Mean, median mode, STD

# %%
# Get numerical columns
numerical_cols = df.select_dtypes(include=[np.number]).columns
stats = df[numerical_cols].agg(['mean', 'median','std']).round(3)
mode = df[numerical_cols].mode().iloc[0].round(3)
print("modes: ")
print(mode)
print("\n\nother stats: ")
print(stats)
# Out:
# modes:
# Rank                             1.000
# 2022 Population                510.000
# 2020 Population                520.000
# 2015 Population                564.000
# 2010 Population                596.000
# 2000 Population                651.000
# 1990 Population                700.000
# 1980 Population                733.000
# 1970 Population                752.000
# Area (km²)                      21.000
# Density (per km²)                0.026
# Growth Rate                      1.004
# World Population Percentage      0.000
# Name: 0, dtype: float64
#
# other stats:
#               Rank  2022 Population  2020 Population  2015 Population  \
# mean    117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# median  117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# std      67.694165     1.367664e+08     1.355899e+08     1.304050e+08
#
#         2010 Population  2000 Population  1990 Population  1980 Population  \
# ...
