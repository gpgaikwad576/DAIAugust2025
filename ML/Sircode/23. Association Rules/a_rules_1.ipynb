# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from ipywidgets import widgets, interact
import os
os.chdir("C:/Python/Datasets")

# %%
fp_df = pd.read_csv('Faceplate.csv',index_col=0)
fp_df.head()

# %%
fp_df = fp_df.astype(bool) # convert to boolean for compatibility of apriori( )
itemsets = apriori(fp_df, min_support=0.2, use_colnames=True)
rules = association_rules(itemsets, metric='confidence',  min_threshold=0.6)
rules = rules[['antecedents','consequents','support', 'confidence','lift']]
rules
# Out:
#       antecedents   consequents  support  confidence      lift
# 0           (Red)       (White)      0.4    0.666667  0.952381
# 1          (Blue)         (Red)      0.4    0.666667  1.111111
# 2           (Red)        (Blue)      0.4    0.666667  1.111111
# 3         (Green)         (Red)      0.2    1.000000  1.666667
# 4          (Blue)       (White)      0.4    0.666667  0.952381
# 5        (Orange)       (White)      0.2    1.000000  1.428571
# 6         (Green)       (White)      0.2    1.000000  1.428571
# 7  (White, Green)         (Red)      0.2    1.000000  1.666667
# 8    (Red, Green)       (White)      0.2    1.000000  1.428571
# 9         (Green)  (White, Red)      0.2    1.000000  2.500000

# %%
def create_rules(min_supp, conf_thres):
    itemsets = apriori(fp_df, min_support=min_supp, use_colnames=True)
    rules = association_rules(itemsets, metric='confidence',  min_threshold=conf_thres)
    rules = rules[['antecedents','consequents','support', 'confidence','lift']]
    return rules
widgets.interact(create_rules, min_supp=(0.01, 1, 0.01), 
                 conf_thres=(0.01, 1, 0.01))
# Out:
# interactive(children=(FloatSlider(value=0.5, description='min_supp', max=1.0, min=0.01, step=0.01), FloatSlide…
# <function __main__.create_rules(min_supp, conf_thres)>

# %% [markdown]
# #### Cosmetics

# %%
cosmetics = pd.read_csv("Cosmetics.csv", index_col=0)
cosmetics = cosmetics.astype(bool)
def create_rules(min_supp, conf_thres):
    itemsets = apriori(cosmetics, min_support=min_supp, use_colnames=True)
    rules = association_rules(itemsets, metric='confidence',  min_threshold=conf_thres)
    rules = rules[['antecedents','consequents','support', 'confidence','lift']]
    return rules
widgets.interact(create_rules, min_supp=(0.01, 1, 0.01), 
                 conf_thres=(0.01, 1, 0.01))
# Out:
# interactive(children=(FloatSlider(value=0.5, description='min_supp', max=1.0, min=0.01, step=0.01), FloatSlide…
# <function __main__.create_rules(min_supp, conf_thres)>
