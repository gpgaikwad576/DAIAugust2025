# %%
import pickle
import pandas as pd

# %%
a=pickle.load(open(r"C:\Users\dai\Desktop\Practical ML\4_nov\best_model.pkl","rb"))

# %%
feature_names = ["satisfaction_level", "last_evaluation", "number_project", 
                 "average_montly_hours", "time_spend_company", "Work_accident", 
                 "promotion_last_5years", "Department", "salary"] 

# Create a DataFrame for the single new observation
new_data = pd.DataFrame(
    [[0.38, 0.53, 2, 157, 3, 1, 0, "sales", "low"]], 
    columns=feature_names
)

print(new_data)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
#
#    time_spend_company  Work_accident  promotion_last_5years Department salary
# 0                   3              1                      0      sales    low

# %%
predict=a.predict(new_data)

# %%
print(f"Predicted Class: {predict[0]}")
# Out:
# Predicted Class: 1
