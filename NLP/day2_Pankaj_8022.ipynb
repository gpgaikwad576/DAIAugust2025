# %%
from polyglot.text import Word

# %%
words = ['cats','computing','association','programming','leadership','miscommunication','identifiable','psychologically','engineering','tabular','realistic','colorfulness']

# %%
for w in words:
    w = Word(w,language = 'en')
    print(w,'\t\r',w.morphemes)
# Out:
#  ['cat', 's']
#  ['com', 'put', 'ing']
#  ['associ', 'ation']
#  ['program', 'ming']
#  ['leader', 'ship']
#  ['mis', 'communication']
#  ['identif', 'i', 'able']
#  ['psycho', 'logical', 'ly']
#  ['engine', 'er', 'ing']
#  ['tab', 'ular']
#  ['real', 'istic']
#  ['color', 'ful', 'ness']

# %%
mwords = ['राज्य्शस्त्र', 'जलविद्युत', 'महाद्विप्']
for w in mwords:
    w = Word(w,language = 'mr')
    print(w,'\t\r',w.morphemes)
# Out:
#  ['राज्य', '्', 'शस्त्र']
#  ['जल', 'विद्युत']
#  ['महा', 'द्वि', 'प्']

# %%
from polyglot.text import Text

# %%
gdata = 'wewillmeettoday'
t = Text(data)
t.morphemes
# Out:
# Detector is not able to detect the language reliably.
# WordList(['we', 'will', 'meet', 'to', 'day'])
