# %%
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import SpaceTokenizer
from nltk.tokenize import TabTokenizer,LineTokenizer,WhitespaceTokenizer,MWETokenizer,TweetTokenizer

# %%
nltk.download("punkt") #tokenization
nltk.download("punkt_tab") #tokenization
nltk.download("averaged_perceptron_tagger") #POS Tagging
nltk.download("averaged_perceptron_tagger_eng") #POS Tagging for ENGLISH

nltk.download("wordnet") #word net vocabulary
nltk.download("stopwords") #stopwords vocabulary
nltk.download("omw-1.4") # stemming and lemmatization
nltk.download("indian") #Indian language POS tagging
nltk.download("maxent_ne_chunker") #POS Tagging

# %%
# sent = "They told that their ages are 26 31 and 29 respectively!"
# #Wrte a program to find the average of ages mentioned in the sentence

# result = re.findall(r"\d+",sent)
# l =list(map(int,result))
# print(sum(l)/len(l))

# %%
sents="Hello friends! How are you? welcome to python programming"
sents1="Hello friends! How are you?\nwelcome to python programming"

# %%
sent1 = "Dr. Deshmukh told Mrs. Sunita to take rest."

# %%
tokens = word_tokenize(sent1)
tokens

# %% [markdown]
# ## **Sentence tokenizer**

# %%
sent_tokenize(sents)

# %%
sent_tokenize(sents1)

# %%
import string
#Find percentages of punctuations present in this sentence
sents="Hello friends! How are you? welcome to python programming."
a=word_tokenize(sents)
count =0
# for c in a:
#     if c in string.punctuation:
#         count=count+1

# count/len(a) *100

len([ i for i in a if i in string.punctuation])/len(a) *100

# %%
len([ i for i in a if i in string.punctuation])/len(a) *100

# %%
text = '''पुणे भारत के महाराष्ट्र राज्य का एक महत्त्वपूर्ण शहर है। पुणे भारत का छठवां सबसे बड़ा शहर व महाराष्ट्र का दूसरा सबसे बड़ा शहर है।.[5] यह शहर महाराष्ट्र के पश्चिम भाग, मुला व मुठा इन दो नदियों के किनारे बसा है और पुणे जिला का प्रशासकीय मुख्यालय है। सार्वजनिक सुखसुविधा व विकास के हिसाब से पुणे महाराष्ट्र मे मुंबई के बाद अग्रसर है। [6][7])अनेक नामांकित शिक्षणसंस्थायें होने के कारण इस शहर को 'पूरब का ऑक्सफोर्ड' भी कहा जाता है। पुणे में अनेक प्रौद्योगिकी और ऑटोमोबाईल उपक्रम हैं, इसलिए पुणे भारत का ”डेट्राइट” जैसा लगता है। काफी प्राचीन ज्ञात इतिहास से पुणे शहर महाराष्ट्र की 'सांस्कृतिक राजधानी' माना जाता है। मराठी भाषा इस शहर की मुख्य भाषा है।

पुणे शहर मे लगभग सभी विषयों के उच्च शिक्षण की सुविधा उपलब्ध है। पुणे विद्यापीठ, राष्ट्रीय रासायनिक प्रयोगशाला, आयुका, आगरकर संशोधन संस्था, सी-डैक जैसी आन्तरराष्ट्रीय स्तर के शिक्षण संस्थान यहाँ है। पुणे फिल्म इन्स्टिट्युट भी काफी प्रसिद्ध है।

पुणे महाराष्ट्र व भारत का एक महत्त्वपूर्ण औद्योगिक केन्द्र है। टाटा मोटर्स, बजाज ऑटो, भारत फोर्ज जैसे उत्पादनक्षेत्र के अनेक बड़े उद्योग यहाँ है। 1990 के दशक मे इन्फोसिस, टाटा कंसल्टंसी सर्विसे, विप्रो, सिमैंटेक, आईबीएम जैसे प्रसिद्ध सॉफ्टवेअर कंपनियों ने पुणे मे अपने केन्द्र खोले और यह शहर भारत का एक प्रमुख सूचना प्रौद्योगिकी उद्योगकेन्द्र के रूप मे विकसित हुआ।

2024 में पुणे की अनुमानित जनसंख्या 10,480,787 है'''

# %%
print(word_tokenize(text),end=" ")

# %%
sent_tokenize(text)

# %%
n_text="""Pune (Marathi: Puṇē, pronounced [ˈpuɳe] ⓘ POO-nay), previously spelled 
in English as Poona (the official name until 1978),[15][16] is a city in the state of Maharashtra in the Deccan Plateau in Western
India. It is the administrative headquarters of the Pune district, and of Pune division. In terms of the total amount of land
under its jurisdiction, Pune is the largest city in Maharashtra by area, with a geographical area of 516.18 km2,[17] though by
population it comes in a distant second to Mumbai. According to the 2011 Census of India, Pune has 7.2 million residents in the 
metropolitan region, making it the seventh-most populous metropolitan area in India.[18] The city of Pune is part of Pune 
Metropolitan Region.[19] Pune is one of the largest IT hubs in India.[20][21] It is also one of the most important automobile
and manufacturing hubs of India. 
Pune is often referred to as the "Oxford of the East" because of its educational institutions.[22][23][24] 
It has been ranked "the most liveable city in India" several times.[25][26]"""

# %%
a=word_tokenize(n_text)
count =0
# for c in a:
#     if c in string.punctuation:
#         count=count+1

# count/len(a) *100

len([ i for i in a if i.lower() in ["the"]])

# %%
tk=WordPunctTokenizer()

# %%
tk.tokenize(n_text)

# %% [markdown]
# ## **Space Tokenizer**

# %%
tk=SpaceTokenizer()

# %%
tk.tokenize(n_text)

# %% [markdown]
# ## **Tab Tokenizer**

# %%
tk=TabTokenizer()
sentence="Hello friends! How are\tyou?\nWelcome to Python\tProgramming."
print(sentence)

# %%
tk.tokenize(sentence)

# %% [markdown]
# ## **Line Tokenizer**

# %%
tk=LineTokenizer()

# %%
tk.tokenize(sentence)

# %% [markdown]
# ## **Whitespace Tokenizer**

# %%
tk=WhitespaceTokenizer()

# %%
tk.tokenize(sentence)

# %% [markdown]
# ## **Multi-Word Expression Tokenizer**

# %%
tk=MWETokenizer(separator=" ")

# %%
sent2="Chhatrapati Shivaji Maharaj is the founder of the Maratha Empire"

# %%
tk.add_mwe(("Chhatrapati","Shivaji"))

# %%
tk.tokenize(word_tokenize(sent2))

# %% [markdown]
# ## **Tweet Tokenizer**

# %%
data = "Hello friends!:) How are you?🥷🏼 Welcome 👩‍🦱 to Python🥪 <3Programming.😸"

# %%
tk=TweetTokenizer()

# %%
a=tk.tokenize(data)

# %%
import emoji
l=emoji.emoji_list(data)
l

# %%
emoji=[]
for token in tk.tokenize(data):
    if not token.isalpha() and not token.isdigit() and token not in string.punctuation:
            emoji.append(token)
emoji

# %% [markdown]
# ## **Custom Tokenizer**

# %%
def custom_tokenizer(text):
    return re.split(r"[,.;?!\s]+",text)

text="This is some text with punctuation > Let's tokenize it. Is it ok?"

# %%
custom_tokenizer(text)
