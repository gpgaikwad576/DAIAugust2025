# %%
from textblob import TextBlob

# %%
word = 'computer'
blob = TextBlob(word)
blob.correct()
# Out:
# TextBlob("computer")

# %%
word = 'komputer'
blob = TextBlob(word)
blob.correct()
# Out:
# TextBlob("computer")

# %%
sent = 'It waas a graet day.'
blob = TextBlob(sent)
blob.correct()
# Out:
# TextBlob("It was a great day.")

# %%
blob.word_counts
# Out:
# defaultdict(int, {'it': 1, 'waas': 1, 'a': 1, 'graet': 1, 'day': 1})

# %%
blob.pos_tags
# Out:
# [('It', 'PRP'), ('waas', 'VBZ'), ('a', 'DT'), ('graet', 'JJ'), ('day', 'NN')]

# %%
blob.tokenize()
# Out:
# WordList(['It', 'waas', 'a', 'graet', 'day', '.'])

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
blob.sentences
# Out:
# [Sentence("It waas a graet day.")]
