# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %% [markdown]
# 1. Create two CSV file with three columns viz. Tom, Brick, Harry with index ‘True’ and ‘False’.
# Each column must contain at least ten values each as a combination of datatypes.

# %%
data={"Index":[True if x%2==0 else False for x in range(0,10)],
    "Tom":np.random.randint(0,100,10),
    "Brick":np.random.randint(0,100,10),
    "Harry":np.random.randint(0,100,10)}
df=pd.DataFrame(index=data['Index'],data=data)
df.drop('Index',inplace=True,axis=1)
df.to_csv(os.path.join(os.getcwd(),'out.csv'))

# %% [markdown]
# 2. Create a data frame with at least 5 columns and 10 rows. There must be some missing
# values in it. If the integer column contains missing values replace it with some statistical
# approach. Also, if there is any missing values in String column, drop the rows using some
# looping function.

# %%
data = {
    'ProductID': [101, 102, 103, 104, 105, 106, 105, 108, 109, 110],
    'Price_USD': [19.99, 25.50, 15.00, np.nan, 30.25, 12.50, 45.00, 22.00, 17.75, 50.00],
    'Stock_Count': [50, 120, np.nan, 75, np.nan, 90, 15, 180, np.nan, 60], # Integer column with missing values
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Home', 'Clothing', np.nan, 'Electronics', 'Clothing', np.nan, 'Electronics'],
    'Rating': [4.5, 3.9, np.nan, 4.8, 4.2, 3.5, 4.9, 4.1, 3.0, 4.7]
}

df=pd.DataFrame(data)

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)
index_value=[]
for index,data in df.iterrows():
    if sum([1 if pd.isnull(x) else 0 for x in data])>0:
        index_value.append(index)
df.drop(index_value)
# Out:
#    ProductID  Price_USD  Stock_Count     Category    Rating
# 0        101  19.990000    50.000000  Electronics  4.500000
# 1        102  25.500000   120.000000     Clothing  3.900000
# 2        103  15.000000    84.285714  Electronics  4.177778
# 3        104  26.443333    75.000000         Home  4.800000
# 4        105  30.250000    84.285714     Clothing  4.200000
# 6        105  45.000000    15.000000  Electronics  4.900000
# 7        108  22.000000   180.000000     Clothing  4.100000
# 9        110  50.000000    60.000000  Electronics  4.700000

# %% [markdown]
# 3. Create a data frame with at least 5 columns and 10 rows. Each column must contain only
# integer elements only. Column names must be Abilash, Ankit, Ashok, Asif, Anjaan. Now
# apply a function where we want to club together the data based on any row or column.
# Group the series using a mapper or by a series of columns.m

# %%
def data_sum(rows):
    return sum([x for x in rows])

# %%
np.random.seed(42)
data = {
    'Abilash': np.random.randint(10, 100, size=10),
    'Ankit': np.random.randint(50, 150, size=10),
    'Ashok': np.random.randint(1, 50, size=10),
    'Asif': np.random.randint(200, 300, size=10),
    'Anjaan': np.random.randint(5, 25, size=10)
}
df=pd.DataFrame(data)
df['Row_Total']=df.apply(data_sum,axis=1)
# pd.concat([df,pd.DataFrame(df.apply(data_sum,axis=0),index=False)],axis=0)
pd.concat([df,df.sum(axis=0).to_frame().T.rename(index={0: 'Col_Total'})])
# Out:
#            Abilash  Ankit  Ashok  Asif  Anjaan  Row_Total
# 0               61    149     21   259       7        497
# 1               24     73     33   279       9        418
# 2               81     52     12   214      23        382
# 3               70     71     22   261      11        435
# 4               30    102     44   261      13        450
# 5               92     51     25   246      11        425
# 6               96    137     49   261      22        565
# 7               84     79     27   250       8        448
# 8               84     87     42   254      18        485
# 9               97     51     28   263      22        461
# Col_Total      719    852    303  2548     144       4566

# %% [markdown]
# 4. Read the CountryDataIND.csv file and perform statistical operation on the same about the
# dataset. Look for any missing data if any.m

# %%
df=pd.read_csv(r"C:\Users\dai\Downloads\Data Sets\Data Sets\CountryDataIND.csv")
df
# Out:
#     Series Code Frequency                                             Series  \
# 0   IT_USE_ii99    Annual                                     Internet users
# 1   IT_USE_ii99    Annual                                     Internet users
# 2   IT_USE_ii99    Annual                                     Internet users
# 3   SE_ADT_1524    Annual                                      Literacy rate
# 4   SE_ADT_1524    Annual                                      Literacy rate
# 5   SH_DYN_MORT    Annual                          Under-five mortality rate
# 6   SH_DYN_MORT    Annual                          Under-five mortality rate
# 7   SH_DYN_MORT    Annual                          Under-five mortality rate
# 8   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 9   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 10  SH_STA_BRTC    Annual        Births attended by skilled health personnel
# ...

# %%
df.drop('Footnotes',axis=1,inplace=True)
df
# Out:
#     Series Code Frequency                                             Series  \
# 0   IT_USE_ii99    Annual                                     Internet users
# 1   IT_USE_ii99    Annual                                     Internet users
# 2   IT_USE_ii99    Annual                                     Internet users
# 3   SE_ADT_1524    Annual                                      Literacy rate
# 4   SE_ADT_1524    Annual                                      Literacy rate
# 5   SH_DYN_MORT    Annual                          Under-five mortality rate
# 6   SH_DYN_MORT    Annual                          Under-five mortality rate
# 7   SH_DYN_MORT    Annual                          Under-five mortality rate
# 8   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 9   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 10  SH_STA_BRTC    Annual        Births attended by skilled health personnel
# ...

# %%
df.describe()
# Out:
#        Time period  Observation Value  Time period details
# count    29.000000          29.000000            29.000000
# mean   1999.551724         140.806897          1999.551724
# std       4.807629         156.922569             4.807629
# min    1990.000000           0.200000          1990.000000
# 25%    1998.000000          27.500000          1998.000000
# 50%    2000.000000          48.500000          2000.000000
# 75%    2004.000000         301.000000          2004.000000
# max    2006.000000         503.000000          2006.000000

# %% [markdown]
# 5. Plot a histogram by keeping the bin size to 10 for the column name = ‘Observation Value’.
# Also Plot a scatter plot between ‘observation Value’ and ‘Time Period’m

# %%
sns.histplot(data=df,x='Observation Value',bins=10,kde=True)
# Out:
# <Axes: xlabel='Observation Value', ylabel='Count'>

# %%
sns.scatterplot(x='Time period', y='Observation Value', data=df)
# Out:
# <Axes: xlabel='Time period', ylabel='Observation Value'>

# %% [markdown]
# Q2
# Suppose you have landed to a job and the first task you’ve assigned to prepare a report which
# includes the following:

# %%
df=pd.read_csv(r"C:\Users\dai\Downloads\Data Sets\Data Sets\purchase_data.csv")
df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
df.isnull().sum()
# Out:
# Purchase ID    0
# SN             0
# Age            0
# Gender         0
# Item ID        0
# Item Name      0
# Price          0
# dtype: int64

# %%
df.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   92.114103    3.050987
# std     225.310896    6.659444   52.775943    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   48.000000    1.980000
# 50%     389.500000   22.000000   93.000000    3.150000
# 75%     584.250000   25.000000  139.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %% [markdown]
# 1. Player Count
# o Total Number of Players

# %%
df['SN'].nunique()
# Out:
# 576

# %% [markdown]
# 2. Purchasing Analysis (Total)
# o Number of Unique Items
# o Average Purchase Price
# o Total Number of Purchases
# o Total Revenue

# %%
df['Item Name'].nunique()
# Out:
# 179

# %%
df['Price'].mean()
# Out:
# np.float64(3.0509871794871795)

# %%
df['Purchase ID'].count()
# Out:
# np.int64(780)

# %%
df['Price'].sum()
# Out:
# np.float64(2379.77)

# %% [markdown]
# 3. Gender Demographics
# o Percentage and Count of Male Players
# o Percentage and Count of Female Players
# o Percentage and Count of Other / Non-Disclosed

# %%
x=df['Gender'].value_counts()
x=x.to_frame()
x['Percentage']=df['Gender'].value_counts()/df['Gender'].count()
x
# Out:
#                        count  Percentage
# Gender
# Male                     652    0.835897
# Female                   113    0.144872
# Other / Non-Disclosed     15    0.019231

# %% [markdown]
# 4. Purchasing Analysis (Gender)
# o The below each broken by gender
#  Purchase Count
#  Average Purchase Price
#  Total Purchase Value
#  Average Purchase Total per Person by Gender

# %%
df.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
df.groupby('Gender')['Purchase ID'].count().to_frame(name="Purchase Count")
# Out:
#                        Purchase Count
# Gender
# Female                            113
# Male                              652
# Other / Non-Disclosed              15

# %%
df.groupby('Gender')['Price'].mean().to_frame(name="Average_Purchase Price")
# Out:
#                        Average_Purchase Price
# Gender
# Female                               3.203009
# Male                                 3.017853
# Other / Non-Disclosed                3.346000

# %%
df.groupby('Gender')['Price'].sum().to_frame(name="Purchase Total")
# Out:
#                        Purchase Total
# Gender
# Female                         361.94
# Male                          1967.64
# Other / Non-Disclosed           50.19

# %%
x_data=df.groupby('Gender')['Price'].sum().to_frame(name="Total Purchase Price")
x_data['Average_Price_Per_Gender']=x_data['Total Purchase Price']/df.groupby("Gender").nunique()['SN']
x_data
# Out:
#                        Total Purchase Price  Average_Price_Per_Gender
# Gender
# Female                               361.94                  4.468395
# Male                                1967.64                  4.065372
# Other / Non-Disclosed                 50.19                  4.562727

# %% [markdown]
# 5. Age Demographics
# o The below each broken into bins of 4 years (i.e. <10, 10-14, 15-19, etc.)
#  Purchase Count
#  Average Purchase Price
#  Total Purchase Value
#  Average Purchase Total per Person by Age Group

# %%
df['Age_Group']=pd.cut(df['Age'],labels=["<10","10-20",'20-30','30+'],bins=[0,10,20,30,np.inf],right=True,include_lowest=True)
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age_Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     10-20
# 1                          Frenzied Scimitar   1.56       30+
# 2                               Final Critic   4.88     20-30
# 3                                Blindscythe   3.27     20-30
# 4                                       Fury   1.44     20-30

# %%
df.groupby('Age_Group',observed=True)['Purchase ID'].count()
# Out:
# Age_Group
# <10       32
# 10-20    254
# 20-30    402
# 30+       92
# Name: Purchase ID, dtype: int64

# %%
df.groupby('Age_Group',observed=True)['Price'].mean()
# Out:
# Age_Group
# <10      3.405000
# 10-20    3.063622
# 20-30    2.992687
# 30+      3.147717
# Name: Price, dtype: float64

# %%
df.groupby('Age_Group',observed=True)['Price'].sum()
# Out:
# Age_Group
# <10       108.96
# 10-20     778.16
# 20-30    1203.06
# 30+       289.59
# Name: Price, dtype: float64

# %%
x_data=df.groupby('Age_Group',observed=True)['Price'].sum().to_frame(name="Total Purchase Price")
x_data['Average_Price_Per_Gender']=x_data['Total Purchase Price']/df.groupby("Age_Group",observed=True).nunique()['SN']
x_data
# Out:
#            Total Purchase Price  Average_Price_Per_Gender
# Age_Group
# <10                      108.96                  4.540000
# 10-20                    778.16                  4.074136
# 20-30                   1203.06                  4.134227
# 30+                      289.59                  4.137000

# %% [markdown]
# 6. Top Spenders
# o Identify the the top 5 spenders in the game by total purchase value, then list (in a
# table):
#
#  SN
#  Purchase Count
#  Average Purchase Price
#  Total Purchase Value

# %%
x_data=df.groupby('SN').agg(Purchase_Count=("Purchase ID","count"),Avg_Purchase_price=("Price",'mean'),Total_purchase_value=("Price",'sum'))
x_data.sort_values("Total_purchase_value",ascending=False).head()
# Out:
#              Purchase_Count  Avg_Purchase_price  Total_purchase_value
# SN
# Lisosia93                 5            3.792000                 18.96
# Idastidru52               4            3.862500                 15.45
# Chamjask73                3            4.610000                 13.83
# Iral74                    4            3.405000                 13.62
# Iskadarya95               3            4.366667                 13.10

# %% [markdown]
#      7. Most Popular Items
# o Identify the 5 most popular items by purchase count, then list (in a table):
#  Item ID
#  Item Name
#  Purchase Count
#  Item Price
#  Total Purchase Value

# %%
x_data=df.groupby('Item ID').agg(Purchase_count=('Purchase ID','count'),Total_purchase_value=('Price','sum'))
x_data['Item_price']=x_data['Total_purchase_value']/x_data['Purchase_count']
x_data.sort_values(by='Purchase_count',ascending=False).head()
# Out:
#          Purchase_count  Total_purchase_value  Item_price
# Item ID
# 178                  12                 50.76        4.23
# 82                    9                 44.10        4.90
# 145                   9                 41.22        4.58
# 108                   9                 31.77        3.53
# 19                    8                  8.16        1.02

# %% [markdown]
# 8. Most Profitable Items
# o the 5 most profitable items by total purchase value, then list (in a table):
#  Item ID
#  Item Name
#  Purchase Count
#  Item Price
#  Total Purchase Value

# %%
x_data.sort_values(by="Total_purchase_value",ascending=False).head()
# Out:
#          Purchase_count  Total_purchase_value  Item_price
# Item ID
# 178                  12                 50.76        4.23
# 82                    9                 44.10        4.90
# 145                   9                 41.22        4.58
# 92                    8                 39.04        4.88
# 103                   8                 34.80        4.35

# %% [markdown]
# ## QQ normal cetral limit theorem uniform

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.histplot(np.random.choice([1,2,3,4,5,6],10000),stat='probability',binwidth=0.4,discrete=True)
# Out:
# <Axes: ylabel='Probability'>

# %% [markdown]
# ## Right skewee graph

# %%
data=np.random.exponential(scale=2,size=10000)
sns.histplot(data,kde=True,bins=100)
plt.title('Right Skewed')
# Out:
# Text(0.5, 1.0, 'Right Skewed')

# %% [markdown]
# ## Normal Disrtibution

# %%
data=np.random.normal(1,3,1000)
sns.histplot(data,kde=True,discrete=True,stat='density')
plt.title('Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Normal Distribution')

# %% [markdown]
# ## QQ plot

# %%
import statsmodels.api as sm
data = np.random.normal(loc=10, scale=2, size=1000)
sns.histplot(data,kde=True,discrete=True,stat='density')
fig=sm.qqplot(data,fit=True,line='45')

# %% [markdown]
# ## Central limit Theorem

# %%
data=np.zeros((1000,30))
for i in range(0,len(data)):
    data[i]=np.random.randint(0,1000,30)

data_means=[values.mean() for values in data]
sns.histplot(data_means,kde=True)
# Out:
# <Axes: ylabel='Count'>
