# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
l=[]

for i in range(0,10000000):
    x=np.random.choice([1,2,3,4,5,6],1)[0]
    l.append(x)
s=pd.Series(l)
sns.histplot(x=s,stat="probability",discrete=True,color='darkblue',shrink=0.8)
# Out:
# <Axes: xlabel='None', ylabel='Probability'>
