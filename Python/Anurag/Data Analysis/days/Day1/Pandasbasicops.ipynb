# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Series

# %%
s=pd.Series({"Anurag":42,"vaibhav":35,"double Fake achintya":99})
s
# Out:
# Anurag                  42
# vaibhav                 35
# double Fake achintya    99
# dtype: int64

# %%
print(s.index,s.values)
# Out:
# Index(['Anurag', 'vaibhav', 'double Fake achintya'], dtype='object') [42 35 99]

# %% [markdown]
# ## DataFrame

# %%
df=pd.read_csv(r"C:\Users\dai\Downloads\tips.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df.iloc[:,:5]
# Out:
#      total_bill   tip  gender smoker   day
# 0         16.99  1.01  Female     No   Sun
# 1         10.34  1.66    Male     No   Sun
# 2         21.01  3.50    Male     No   Sun
# 3         23.68  3.31    Male     No   Sun
# 4         24.59  3.61  Female     No   Sun
# ..          ...   ...     ...    ...   ...
# 239       29.03  5.92    Male     No   Sat
# 240       27.18  2.00  Female    Yes   Sat
# 241       22.67  2.00    Male    Yes   Sat
# 242       17.82  1.75    Male     No   Sat
# 243       18.78  3.00  Female     No  Thur
#
# [244 rows x 5 columns]

# %%
df[['total_bill','tip']].head(5)
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
df['tip_percentage']=df['tip']*100/df['total_bill']
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID  tip_percentage
# ...

# %%
df_sorted=df.reindex(sorted(df.columns),axis=1)
df_sorted.head(5)
# Out:
#       CC Number          Payer Name Payment ID  day  gender  price_per_person  \
# 0  3.560330e+15  Christy Cunningham    Sun2959  Sun  Female              8.49
# 1  4.478070e+15      Douglas Tucker    Sun4608  Sun    Male              3.45
# 2  6.011810e+15      Travis Walters    Sun4458  Sun    Male              7.00
# 3  4.676140e+15    Nathaniel Harris    Sun5260  Sun    Male             11.84
# 4  4.832730e+15        Tonya Carter    Sun2251  Sun  Female              6.15
#
#    size smoker    time   tip  tip_percentage  total_bill
# 0     2     No  Dinner  1.01        5.944673       16.99
# 1     3     No  Dinner  1.66       16.054159       10.34
# 2     3     No  Dinner  3.50       16.658734       21.01
# 3     2     No  Dinner  3.31       13.978041       23.68
# 4     4     No  Dinner  3.61       14.680765       24.59

# %%
df_cust_col_=df_sorted[['Payment ID','Payer Name','gender',"day",'time','smoker','size','tip','total_bill','tip_percentage','price_per_person','CC Number']]
df_cust_col_
# Out:
#     Payment ID          Payer Name  gender   day    time smoker  size   tip  \
# 0      Sun2959  Christy Cunningham  Female   Sun  Dinner     No     2  1.01
# 1      Sun4608      Douglas Tucker    Male   Sun  Dinner     No     3  1.66
# 2      Sun4458      Travis Walters    Male   Sun  Dinner     No     3  3.50
# 3      Sun5260    Nathaniel Harris    Male   Sun  Dinner     No     2  3.31
# 4      Sun2251        Tonya Carter  Female   Sun  Dinner     No     4  3.61
# ..         ...                 ...     ...   ...     ...    ...   ...   ...
# 239    Sat2657       Michael Avila    Male   Sat  Dinner     No     3  5.92
# 240    Sat1766      Monica Sanders  Female   Sat  Dinner    Yes     2  2.00
# 241    Sat3880          Keith Wong    Male   Sat  Dinner    Yes     2  2.00
# 242      Sat17        Dennis Dixon    Male   Sat  Dinner     No     2  1.75
# 243    Thur672     Michelle Hardin  Female  Thur  Dinner     No     2  3.00
#
# ...

# %% [markdown]
# ## Filter Conditions

# %%
df[(df['gender']=="Male") & (df['smoker']=="Yes")].head()
# Out:
#     total_bill   tip gender smoker  day    time  size  price_per_person  \
# 56       38.01  3.00   Male    Yes  Sat  Dinner     4              9.50
# 58       11.24  1.76   Male    Yes  Sat  Dinner     2              5.62
# 60       20.29  3.21   Male    Yes  Sat  Dinner     2             10.14
# 61       13.81  2.00   Male    Yes  Sat  Dinner     2              6.90
# 62       11.02  1.98   Male    Yes  Sat  Dinner     2              5.51
#
#                Payer Name     CC Number Payment ID  tip_percentage
# 56  James Christensen DDS  3.497940e+14    Sat8903        7.892660
# 58          Troy Guerrero  3.560780e+15    Sat6683       15.658363
# 60         Anthony Mclean  3.476140e+14    Sat2353       15.820601
# 61         Ryan Hernandez  4.766830e+12    Sat3030       14.482259
# 62            Joseph Hart  1.800460e+14    Sat2265       17.967332

# %%
df.query("gender=='Female' and tip>=4").head()
# Out:
#     total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 11       35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 52       34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 73       25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 85       34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 93       16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
#
#         Payer Name     CC Number Payment ID
# 11    Diane Macias  4.577820e+15    Sun6686
# 52    Emily Daniel  4.291280e+15    Sun6165
# 73    Julie Holmes  5.418690e+15    Sat6065
# 85     Shawna Cook  6.011790e+15   Thur7972
# 93  Natalie Nguyen  5.181240e+15    Fri6963

# %% [markdown]
# ## ratio of M:F (smoker)

# %%
x=df.groupby(['gender','smoker'])['smoker'].count().to_frame(name='Count')
x['percentage']=(round(x['Count']/x.groupby(level='gender')['Count'].sum()*100,3))
x
# Out:
#                Count  percentage
# gender smoker
# Female No         54      62.069
#        Yes        33      37.931
# Male   No         97      61.783
#        Yes        60      38.217
