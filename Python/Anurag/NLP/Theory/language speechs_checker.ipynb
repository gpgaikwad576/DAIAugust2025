# %%
import language_tool_python
from textblob import TextBlob

# %%
text  = "python It ws a great day"
blob = TextBlob(text)
blob.correct()
# Out:
# TextBlob("patron It was a great day")

# %%
blob.pos_tags
# Out:
# [('python', 'NN'),
#  ('It', 'PRP'),
#  ('ws', 'VBZ'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('day', 'NN')]

# %%
blob.word_counts
# Out:
# defaultdict(int, {'python': 1, 'it': 1, 'ws': 1, 'a': 1, 'great': 1, 'day': 1})

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.8, subjectivity=0.75)

# %%
blob.sentences
# Out:
# [Sentence("python It ws a great day")]

# %%
blob.tokenize()
# Out:
# WordList(['python', 'It', 'ws', 'a', 'great', 'day'])
