# %%
from goslate import Goslate

# %%
trns = Goslate()

# %%
text = "Hello Friends! How are you? I will teach you Python Programming"

trns.translate(text=text,target_language='hi')
# Out:
# 'नमस्कार दोस्तों आप कैसे हैं? मैं तुम्हें पायथन प्रोग्रामिंग सिखाऊंगा'

# %%
trns.get_languages()
# Out:
# {'ab': 'Abkhaz',
#  'ace': 'Acehnese',
#  'ach': 'Acholi',
#  'aa': 'Afar',
#  'af': 'Afrikaans',
#  'sq': 'Albanian',
#  'alz': 'Alur',
#  'am': 'Amharic',
#  'ar': 'Arabic',
#  'hy': 'Armenian',
#  'as': 'Assamese',
#  'av': 'Avar',
#  'awa': 'Awadhi',
#  'ay': 'Aymara',
#  'az': 'Azerbaijani',
#  'ban': 'Balinese',
#  'bal': 'Baluchi',
#  'bm': 'Bambara',
#  'bci': 'Baoulé',
#  'ba': 'Bashkir',
#  'eu': 'Basque',
#  'btx': 'Batak Karo',
#  'bts': 'Batak Simalungun',
#  'bbc': 'Batak Toba',
#  'be': 'Belarusian',
#  'bem': 'Bemba',
#  'bn': 'Bengali',
#  'bew': 'Betawi',
#  'bho': 'Bhojpuri',
#  'bik': 'Bikol',
#  'bs': 'Bosnian',
#  'br': 'Breton',
#  'bg': 'Bulgarian',
#  'bua': 'Buryat',
#  'yue': 'Cantonese',
#  'ca': 'Catalan',
#  'ceb': 'Cebuano',
#  'ch': 'Chamorro',
#  'ce': 'Chechen',
#  'ny': 'Chichewa',
#  'zh-CN': 'Chinese (Simplified)',
#  'chk': 'Chuukese',
#  'cv': 'Chuvash',
#  'co': 'Corsican',
#  'crh': 'Crimean Tatar (Cyrillic)',
# ...

# %%
trns.translate(text=text,target_language='fr')
# Out:
# 'Bonjour les amis ! Comment vas-tu? Je vais vous apprendre la programmation Python'
