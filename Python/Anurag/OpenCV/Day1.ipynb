# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('D:\DAIAugust2025\Python\Anurag\OpenCV\datasets\image_dataset\images\dog.jpg')

type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[123, 188, 166],
#         [123, 188, 166],
#         [124, 189, 167],
#         ...,
#         [117, 184, 163],
#         [116, 183, 162],
#         [115, 182, 161]],
#
#        [[123, 188, 166],
#         [123, 188, 166],
#         [124, 189, 167],
#         ...,
#         [117, 184, 163],
#         [117, 184, 163],
#         [116, 183, 162]],
#
#        [[123, 188, 166],
#         [124, 189, 167],
#         [124, 189, 167],
#         ...,
#         [118, 185, 164],
#         [118, 185, 164],
#         [117, 184, 163]],
#
#        ...,
#
#        [[ 61, 123, 101],
#         [ 60, 122, 100],
#         [ 61, 123, 101],
#         ...,
#         [ 69, 124, 121],
#         [ 67, 122, 119],
#         [ 66, 121, 118]],
#
#        [[ 58, 122, 100],
#         [ 57, 121,  99],
#         [ 58, 120,  98],
#         ...,
#         [ 71, 128, 120],
#         [ 69, 125, 120],
#         [ 71, 125, 120]],
#
#        [[ 56, 121,  99],
#         [ 56, 121,  99],
#         [ 59, 121,  99],
# ...

# %%
img.shape
# Out:
# (400, 401, 3)

# %%
cv.imshow('frame',img)
if cv.waitKey(0) == ord('q'):
    cv.destroyAllWindows()

# %%
img = plt.imread('D:\DAIAugust2025\Python\Anurag\OpenCV\datasets\image_dataset\images\dog.jpg')
plt.imshow(img)
# plt.axis('off')

# %%
image  = cv.imread('datasets\image_dataset\images\cat.jpg')
image = cv.resize(image,(800,400))
gray_img = cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv.imshow('original',image)
cv.imshow('gray',gray_img)

if cv.waitKey(0) == ord('q')  or cv.waitKey(0) ==27:
        cv.destroyAllWindows()

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

def nothing():
    pass

trackbar_window = 'Trackbars'


image  = cv.imread('datasets\image_dataset\images\cat.jpg')
image = cv.resize(image,(400,400))


hsv = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv.namedWindow(trackbar_window)

cv.createTrackbar('H Min', trackbar_window, 0, 255, nothing)
cv.createTrackbar('S Min', trackbar_window, 0, 255, nothing)
cv.createTrackbar('V Min', trackbar_window, 0, 255, nothing)

# Create trackbars for HSV maximum values
cv.createTrackbar('H Max', trackbar_window, 179, 179, nothing)
cv.createTrackbar('S Max', trackbar_window, 255, 255, nothing)
cv.createTrackbar('V Max', trackbar_window, 255, 255, nothing)

while True:
    h_min = cv.getTrackbarPos('H Min',trackbar_window)
    s_min = cv.getTrackbarPos('S Min',trackbar_window)
    v_min = cv.getTrackbarPos('V Min',trackbar_window)

    h_max = cv.getTrackbarPos('H Max',trackbar_window)
    s_max = cv.getTrackbarPos('S Max',trackbar_window)
    v_max = cv.getTrackbarPos('V Max',trackbar_window)


    lower_bound = np.array([h_min, s_min, v_min])
    upper_bound = np.array([h_max, s_max, v_max])

    mask = cv.inRange(hsv, lower_bound, upper_bound)

    result = cv.bitwise_and(image, image, mask=mask)

    cv.imshow('Original Image', image)
    cv.imshow('Masked Result (Color Filter)', result)
    cv.imshow('Mask Only', mask)

    key = cv.waitKey(1) & 0xFF
    if key == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: nothing() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: nothing() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: nothing() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: nothing() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# ...

# %%
img1 = np.zeros((8,8),dtype = np.uint8)
img1 = cv.cvtColor(img1,cv.COLOR_GRAY2RGB)
# plt.imshow(img1)

for i in range(0,8):
    for j in range(0,8):
        if((i+j)%2==0):
            img1[i:i+1,j:j+1]=255


plt.imshow(img1)

# %%
new_img = np.arange(0,225).reshape(15,15)
plt.imshow(new_img,cmap='gray')

# %%
img = plt.imread('D:\DAIAugust2025\Python\Anurag\OpenCV\datasets\image_dataset\images\dog.jpg')
img1=img.copy()
for i in range(img1.shape[0]):
    for j in range(img1.shape[1]):
        if i==j or i+j  == img1.shape[0]:
            img1[i,j] = 0

plt.imshow(img1,cmap= 'gray')
