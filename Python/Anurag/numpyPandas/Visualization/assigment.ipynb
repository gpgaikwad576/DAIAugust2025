# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from collections import defaultdict
def extracttype(data):
    d=pd.DataFrame()
    data=data.split('\n')
    for line in data:
        type=line.split(' ')[2][1:-1]
        message=line.split('-')[-1]
        d=pd.concat([d,pd.DataFrame([{'type':type,'message':message}])])

    d.reset_index(inplace=True)
    d.drop('index',inplace=True,axis=1)

    return d

# %%
with open(r"C:\Users\dai\Desktop\ecommerce_app_detailed.log",'r') as f:
    data=f.read()
    res=extracttype(data)

res
# Out:
#       type                                            message
# 0    DEBUG        Calculating shipping cost for order O817987
# 1    DEBUG      Fetching product P43822 details from database
# 2    ERROR   Failed to send confirmation email for order O...
# 3     INFO   Payment processed successfully for order O968867
# 4    ERROR            Refund process failed for order O292829
# ..     ...                                                ...
# 995  DEBUG                Cache miss for user session S562466
# 996  DEBUG        Building recommendation list for user U5144
# 997   INFO   Payment processed successfully for order O867204
# 998  DEBUG         Validating shipping address for user U9039
# 999  DEBUG   Checking inventory availability for product P...
#
# [1000 rows x 2 columns]

# %%
sns.barplot(res['type'].value_counts(),palette=['aquamarine','magenta','darkred'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
d={'Anurag':1}
d["Anurag"]=d.get('Anurag',0)+1
d
# Out:
# {'Anurag': 2}

# %%
d={'type':list(res.keys()),'cnt':list(res.values())}
d
df=pd.DataFrame(d)
df.columns
# Out:
# 0    DEBUG
# 1    ERROR
# 2     INFO
# Name: type, dtype: object

# %%
plt.bar(df['type'],df['cnt'])
# Out:
# <BarContainer object of 3 artists>

# %%
data=data.split('\n')
data
# Out:
# ['2024-05-03 01:37:46,806 [DEBUG] [ecommerce-app] - Calculating shipping cost for order O817987',
#  '2024-06-07 23:57:21,589 [DEBUG] [ecommerce-app] - Fetching product P43822 details from database',
#  '2024-05-03 17:27:51,643 [ERROR] [ecommerce-app] - Failed to send confirmation email for order O504101',
#  '2024-05-07 21:54:13,114 [INFO] [ecommerce-app] - Payment processed successfully for order O968867',
#  '2024-05-07 06:59:51,296 [ERROR] [ecommerce-app] - Refund process failed for order O292829',
#  '2024-05-22 19:05:55,166 [INFO] [ecommerce-app] - Shipment created for order O606276',
#  '2024-05-22 15:16:15,233 [INFO] [ecommerce-app] - Inventory updated for product P42142',
#  '2024-06-04 09:12:13,459 [INFO] [ecommerce-app] - User U6955 updated profile information',
#  '2024-06-23 05:54:27,763 [ERROR] [ecommerce-app] - Failed to send confirmation email for order O762463',
# ...

# %%
c=pd.DataFrame()

r=pd.concat([c,pd.DataFrame([{'name':'Anurag','message':'scas'}])])
r
# Out:
#      name message
# 0  Anurag    scas

# %%
print(data[0].split('-')[-1])
# Out:
#  Calculating shipping cost for order O817987

# %%
res.reset_index(inplace=True)

# %%
res=res.drop('index',axis=1)
res
# Out:
#       type                                            message
# 0    DEBUG        Calculating shipping cost for order O817987
# 1    DEBUG      Fetching product P43822 details from database
# 2    ERROR   Failed to send confirmation email for order O...
# 3     INFO   Payment processed successfully for order O968867
# 4    ERROR            Refund process failed for order O292829
# ..     ...                                                ...
# 995  DEBUG                Cache miss for user session S562466
# 996  DEBUG        Building recommendation list for user U5144
# 997   INFO   Payment processed successfully for order O867204
# 998  DEBUG         Validating shipping address for user U9039
# 999  DEBUG   Checking inventory availability for product P...
#
# [1000 rows x 2 columns]

# %%
res['type'].value_counts()
# Out:
# type
# DEBUG    365
# ERROR    321
# INFO     314
# Name: count, dtype: int64

# %%
res.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
plt.bar(res['type'],res['type'].value_counts()[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 plt.bar(res['type'],res['type'].value_counts())
#
# File D:\DAIAugust2025\Python\Anurag\.venv\Lib\site-packages\matplotlib\pyplot.py:2990, in bar(x, height, width, bottom, align, data, **kwargs)
#    2979 @_copy_docstring_and_deprecators(Axes.bar)
#    2980 def bar(
#    2981     x: float | ArrayLike,
#    (...)   2988     **kwargs,
#    2989 ) -> BarContainer:
# -> 2990     return gca().bar(
#    2991         x,
#    2992         height,
#    2993         width=width,
#    2994         bottom=bottom,
#    2995         align=align,
#    2996         **({"data": data} if data is not None else {}),
#    2997         **kwargs,
#    2998     )
#
# File D:\DAIAugust2025\Python\Anurag\.venv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
# ...

# %%
sns.barplot(res['type'].value_counts())
# Out:
# <Axes: xlabel='type', ylabel='count'>
