# %% [markdown]
# Your Name and PRN:
# - Name : Anurag Sahu
# - PRN  : 250840128011
# - Date : 23 Nov 2025

# %%
###-----------------
### Import libraries
###-----------------
from pathlib import Path  # Import Path for file system path operations and management
import numpy as np  # Import NumPy for numerical computations and array operations
import pandas as pd  # Import Pandas for data manipulation and analysis with DataFrames
import matplotlib.pyplot as plt  # Import Matplotlib for creating static, interactive visualizations
import seaborn as sns  # Import Seaborn for statistical data visualization built on Matplotlib

from sklearn.model_selection import  train_test_split # Import function to split dataset into training and testing subsets
from sklearn.metrics import * # Import function to calculate various metric

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import os

# %%
###----------------------
### Some basic parameters
###----------------------

# inpDir = Path('..') / '..' / 'input'
# outDir = Path('..') / 'output'
# modelDir = Path('..') / 'models'
# subDir = 'fifa_2019'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 100 # number of epochs
BATCH_SIZE = 32
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
# TRAIN_SIZE=int(18*BATCH_SIZE)


WEIGHT_DECAY = 0.001
PATENCE = 20
LR_FACTOR = 0.1
LR_PATIENCE = 5
MIN_LR = 1e-6

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
data_dir = r"D:\dnn_input\flower_photos"
# 2. Define parameters for image loading
IMAGE_SIZE = (190, 190) # Standardize image dimensions
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.2 # 20% of the data will be used for validation

train_datagen = ImageDataGenerator(
    rescale=1./255, # Normalize pixel values to [0, 1]
    rotation_range=20, # Rotate images randomly by up to 20 degrees
    width_shift_range=0.2, # Shift images horizontally by up to 20%
    height_shift_range=0.2, # Shift images vertically by up to 20%
    shear_range=0.2, # Apply shear transformation
    zoom_range=0.2, # Zoom in on images"
    horizontal_flip=True, # Flip images horizontally
    fill_mode='nearest', # Strategy for filling in new pixels created by rotation/shift
    validation_split=VALIDATION_SPLIT # THIS IS KEY for the split
)

# Load the training images from the directory
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical', # Use 'categorical' for multi-class classification
    subset='training', # Specify this is the training set
    seed=42 # Set a seed for reproducibility
)


validation_datagen = ImageDataGenerator(
    rescale=1./255, # Normalize pixel values
    validation_split=VALIDATION_SPLIT # THIS IS KEY for the split
)

# Load the validation images from the directory
validation_generator = validation_datagen.flow_from_directory(
    data_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation', # Specify this is the validation set
    seed=42 # Use the same seed for consistent splitting
)
# Out:
# Found 2939 images belonging to 5 classes.
# Found 731 images belonging to 5 classes.

# %%
# tf.keras.layers.Dropout()

# %%
def build_model(input_shape, num_classes):
    model=tf.keras.Sequential()

    model.add(tf.keras.Input(shape=input_shape))
    #model.add(tf.keras.layers.Rescaling(1./255))
    

    ##SET-1
    model.add(tf.keras.layers.Conv2D(32,(3,3)))#(188x188x32)
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.MaxPool2D())#(94x94x32)
    # model.add(tf.keras.layers.Dropout(0.1))

    ##SET-2
    model.add(tf.keras.layers.Conv2D(64,(3,3)))#(92x92x64)
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.MaxPool2D())#(46x46x64)
    # model.add(tf.keras.layers.Dropout(0.2))

    ##SET-3
    model.add(tf.keras.layers.Conv2D(128,(3,3)))#(44x44x128)
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.MaxPool2D())#(22x22x128)
    # model.add(tf.keras.layers.Dropout(0.3))

    ##SET-4
    model.add(tf.keras.layers.Conv2D(256,(3,3)))#(20x20x256)
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.MaxPool2D())#(10x10x256)
    # model.add(tf.keras.layers.Dropout(0.4))

    ##SET-5
    model.add(tf.keras.layers.Conv2D(512,(3,3)))#(8x8x512)
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.MaxPool2D())#(4x4x512)
    # model.add(tf.keras.layers.Dropout(0.5))


    ##SET-6
    model.add(tf.keras.layers.Conv2D(1024,(3,3)))#(2x2x1024)
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.ReLU())
    # model.add(tf.keras.layers.Dropout(0.2))


    model.add(tf.keras.layers.Flatten())#4096

    ##HEAD
    model.add(tf.keras.layers.Dense(1024))#1024
    # model.add(tf.keras.layers.Dropout(0.01))
    model.add(tf.keras.layers.ReLU())

    model.add(tf.keras.layers.Dense(num_classes))

    return model

# %%
IMAGE_HEIGHT =190
IMAGE_WIDTH =190
model = build_model([IMAGE_HEIGHT,IMAGE_WIDTH,3],train_generator.num_classes)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 188, 188, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 188, 188, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 188, 188, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 94, 94, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 94, 94, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 92, 92, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 92, 92, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 92, 92, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 46, 46, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 46, 46, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 44, 44, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 44, 44, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 44, 44, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 20, 20, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 20, 20, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 20, 20, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 10, 10, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10, 10, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 2, 2, 1024)     │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 2, 2, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 2, 2, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 2, 2, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     4,195,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         5,125 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,496,709 (40.04 MB)
#  Trainable params: 10,492,677 (40.03 MB)
#  Non-trainable params: 4,032 (15.75 KB)

# %%
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=1,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=MIN_LR,
)

es_callback = tf.keras.callbacks.EarlyStopping(

    monitor="val_loss",
    min_delta=0,
    patience=PATENCE,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %% [markdown]
# ## With batchnorm, earlystop

# %%
# model.compile(optimizer=tf.keras.optimizers.Adam(ALPHA),
#               loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# history= model.fit(train_generator,
#                    validation_data=validation_generator,
#                    epochs=EPOCHS,callbacks=[es_callback,lr_callback])

# %%
def plot_graph(history):
    fig,ax = plt.subplots(1,2,figsize=(15,8))
    fig.suptitle('with early stopping')
    keys=list(history.history.keys())
    ax[0].plot(history.epoch,history.history[keys[0]],label=keys[0])
    ax[0].plot(history.epoch,history.history[keys[2]],label=keys[2])
    ax[0].set_title('Accuracy')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend()

    ax[1].plot(history.epoch,history.history[keys[1]],label=keys[1])
    ax[1].plot(history.epoch,history.history[keys[3]],label=keys[2])
    ax[1].set_title('Loss')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()
    

    plt.show()

plot_graph(history)

# %% [markdown]
# # without early stopping,
# # with dropout

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(ALPHA),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history= model.fit(train_generator,
                   validation_data=validation_generator,
                   epochs=EPOCHS)
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.4502 - loss: 1.5712 - val_accuracy: 0.2449 - val_loss: 2.1171
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.5631 - loss: 1.0821 - val_accuracy: 0.2449 - val_loss: 2.9238
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.6155 - loss: 0.9917 - val_accuracy: 0.2462 - val_loss: 3.0857
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.6404 - loss: 0.9379 - val_accuracy: 0.3187 - val_loss: 2.3845
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.6632 - loss: 0.8619 - val_accuracy: 0.5253 - val_loss: 1.2510
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.6727 - loss: 0.8405 - val_accuracy: 0.4802 - val_loss: 1.5366
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.6948 - loss: 0.8009 - val_accuracy: 0.6881 - val_loss: 0.8847
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7023 - loss: 0.7863 - val_accuracy: 0.6772 - val_loss: 0.8642
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.7162 - loss: 0.7414 - val_accuracy: 0.6621 - val_loss: 1.0051
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7145 - loss: 0.7592 - val_accuracy: 0.5896 - val_loss: 1.1203
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7138 - loss: 0.7506 - val_accuracy: 0.6840 - val_loss: 0.8549
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.7207 - loss: 0.7345 - val_accuracy: 0.6005 - val_loss: 1.4501
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7373 - loss: 0.6909 - val_accuracy: 0.7045 - val_loss: 0.7680
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7210 - loss: 0.7061 - val_accuracy: 0.6799 - val_loss: 0.8698
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7458 - loss: 0.6576 - val_accuracy: 0.7182 - val_loss: 0.8236
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.7469 - loss: 0.6645 - val_accuracy: 0.7456 - val_loss: 0.6532
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7537 - loss: 0.6558 - val_accuracy: 0.6689 - val_loss: 0.8601
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.7584 - loss: 0.6316 - val_accuracy: 0.7155 - val_loss: 0.8109
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.7622 - loss: 0.6466 - val_accuracy: 0.6936 - val_loss: 0.8839
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.7748 - loss: 0.6010 - val_accuracy: 0.7661 - val_loss: 0.6795
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7662 - loss: 0.6082 - val_accuracy: 0.7168 - val_loss: 0.8117
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7577 - loss: 0.6110 - val_accuracy: 0.6799 - val_loss: 1.0151
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7727 - loss: 0.5795 - val_accuracy: 0.6908 - val_loss: 0.9088
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.7792 - loss: 0.5896 - val_accuracy: 0.7360 - val_loss: 0.7271
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.7839 - loss: 0.5854 - val_accuracy: 0.7332 - val_loss: 0.7580
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7894 - loss: 0.5525 - val_accuracy: 0.7674 - val_loss: 0.6696
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7802 - loss: 0.5582 - val_accuracy: 0.7387 - val_loss: 0.7678
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.7938 - loss: 0.5610 - val_accuracy: 0.6881 - val_loss: 1.0118
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.8101 - loss: 0.5253 - val_accuracy: 0.6484 - val_loss: 1.4651
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7952 - loss: 0.5540 - val_accuracy: 0.7346 - val_loss: 0.8488
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8064 - loss: 0.5194 - val_accuracy: 0.7674 - val_loss: 0.7470
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8023 - loss: 0.5174 - val_accuracy: 0.6922 - val_loss: 0.9244
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8146 - loss: 0.4954 - val_accuracy: 0.7373 - val_loss: 0.7059
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8156 - loss: 0.5036 - val_accuracy: 0.7579 - val_loss: 0.7204
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8061 - loss: 0.5207 - val_accuracy: 0.6580 - val_loss: 1.0498
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8272 - loss: 0.4733 - val_accuracy: 0.7401 - val_loss: 0.7120
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8139 - loss: 0.4797 - val_accuracy: 0.7415 - val_loss: 0.7420
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8149 - loss: 0.4739 - val_accuracy: 0.7852 - val_loss: 0.5858
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8319 - loss: 0.4412 - val_accuracy: 0.7962 - val_loss: 0.6370
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8156 - loss: 0.4786 - val_accuracy: 0.6539 - val_loss: 1.2348
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8159 - loss: 0.4704 - val_accuracy: 0.7538 - val_loss: 0.8913
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8319 - loss: 0.4391 - val_accuracy: 0.7319 - val_loss: 0.8956
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8299 - loss: 0.4348 - val_accuracy: 0.7770 - val_loss: 0.5634
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.8261 - loss: 0.4455 - val_accuracy: 0.7059 - val_loss: 0.9674
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.8401 - loss: 0.4334 - val_accuracy: 0.7387 - val_loss: 0.8050
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.8438 - loss: 0.4133 - val_accuracy: 0.7770 - val_loss: 0.5804
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.8346 - loss: 0.4247 - val_accuracy: 0.6402 - val_loss: 1.5210
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.8469 - loss: 0.4302 - val_accuracy: 0.7401 - val_loss: 0.7736
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8486 - loss: 0.4084 - val_accuracy: 0.7866 - val_loss: 0.6191
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8391 - loss: 0.4210 - val_accuracy: 0.7565 - val_loss: 0.7485
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8595 - loss: 0.3934 - val_accuracy: 0.7538 - val_loss: 0.7052
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8554 - loss: 0.3822 - val_accuracy: 0.7756 - val_loss: 0.7229
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8561 - loss: 0.3865 - val_accuracy: 0.8057 - val_loss: 0.6126
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8401 - loss: 0.4183 - val_accuracy: 0.7332 - val_loss: 0.7347
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8489 - loss: 0.3948 - val_accuracy: 0.7141 - val_loss: 0.8516
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8493 - loss: 0.4020 - val_accuracy: 0.7100 - val_loss: 1.1374
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8629 - loss: 0.3740 - val_accuracy: 0.7989 - val_loss: 0.5614
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8605 - loss: 0.3675 - val_accuracy: 0.8249 - val_loss: 0.5344
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8646 - loss: 0.3671 - val_accuracy: 0.8235 - val_loss: 0.5355
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8632 - loss: 0.3683 - val_accuracy: 0.8331 - val_loss: 0.5023
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8687 - loss: 0.3436 - val_accuracy: 0.7620 - val_loss: 0.7993
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8687 - loss: 0.3605 - val_accuracy: 0.8235 - val_loss: 0.5545
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8622 - loss: 0.3814 - val_accuracy: 0.8263 - val_loss: 0.5058
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8758 - loss: 0.3278 - val_accuracy: 0.7811 - val_loss: 0.6904
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8629 - loss: 0.3645 - val_accuracy: 0.7839 - val_loss: 0.7102
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8693 - loss: 0.3535 - val_accuracy: 0.8044 - val_loss: 0.5578
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8755 - loss: 0.3425 - val_accuracy: 0.8222 - val_loss: 0.6792
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8707 - loss: 0.3435 - val_accuracy: 0.7921 - val_loss: 0.6251
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8772 - loss: 0.3313 - val_accuracy: 0.8290 - val_loss: 0.5696
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8744 - loss: 0.3344 - val_accuracy: 0.8126 - val_loss: 0.5901
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8697 - loss: 0.3367 - val_accuracy: 0.8181 - val_loss: 0.5730
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8867 - loss: 0.3119 - val_accuracy: 0.7551 - val_loss: 0.8355
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8891 - loss: 0.3084 - val_accuracy: 0.7770 - val_loss: 0.7029
# Epoch 74/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8938 - loss: 0.3077 - val_accuracy: 0.7428 - val_loss: 0.9447
# Epoch 75/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8785 - loss: 0.3359 - val_accuracy: 0.8304 - val_loss: 0.5387
# Epoch 76/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8823 - loss: 0.3183 - val_accuracy: 0.8208 - val_loss: 0.5730
# Epoch 77/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8870 - loss: 0.3111 - val_accuracy: 0.8290 - val_loss: 0.5188
# Epoch 78/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8932 - loss: 0.2821 - val_accuracy: 0.7551 - val_loss: 0.7390
# Epoch 79/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8908 - loss: 0.3076 - val_accuracy: 0.8290 - val_loss: 0.5075
# Epoch 80/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8935 - loss: 0.2965 - val_accuracy: 0.8509 - val_loss: 0.4851
# Epoch 81/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8911 - loss: 0.2851 - val_accuracy: 0.7948 - val_loss: 0.6970
# Epoch 82/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8847 - loss: 0.2997 - val_accuracy: 0.7551 - val_loss: 0.9255
# Epoch 83/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.8826 - loss: 0.3170 - val_accuracy: 0.7989 - val_loss: 0.6752
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8928 - loss: 0.2896 - val_accuracy: 0.7565 - val_loss: 0.7400
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8983 - loss: 0.2736 - val_accuracy: 0.7278 - val_loss: 0.9323
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8942 - loss: 0.2778 - val_accuracy: 0.7770 - val_loss: 0.6413
# Epoch 87/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8979 - loss: 0.2771 - val_accuracy: 0.8208 - val_loss: 0.6164
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.8966 - loss: 0.2820 - val_accuracy: 0.7784 - val_loss: 0.7724
# Epoch 89/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9064 - loss: 0.2702 - val_accuracy: 0.8140 - val_loss: 0.5937
# Epoch 90/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9078 - loss: 0.2718 - val_accuracy: 0.8468 - val_loss: 0.5434
# Epoch 91/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9102 - loss: 0.2616 - val_accuracy: 0.7866 - val_loss: 0.6692
# Epoch 92/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9034 - loss: 0.2603 - val_accuracy: 0.8331 - val_loss: 0.5481
# Epoch 93/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9095 - loss: 0.2529 - val_accuracy: 0.8276 - val_loss: 0.6302
# Epoch 94/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8972 - loss: 0.2850 - val_accuracy: 0.8085 - val_loss: 0.6524
# Epoch 95/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.9054 - loss: 0.2659 - val_accuracy: 0.6758 - val_loss: 1.2613
# Epoch 96/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.9078 - loss: 0.2582 - val_accuracy: 0.7948 - val_loss: 0.5934
# Epoch 97/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9003 - loss: 0.2676 - val_accuracy: 0.7510 - val_loss: 0.7646
# Epoch 98/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.8969 - loss: 0.2846 - val_accuracy: 0.7948 - val_loss: 0.6843
# Epoch 99/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9098 - loss: 0.2426 - val_accuracy: 0.8482 - val_loss: 0.4417
# Epoch 100/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9075 - loss: 0.2396 - val_accuracy: 0.8358 - val_loss: 0.5434

# %%
def plot_graph(history):
    fig,ax = plt.subplots(1,2,figsize=(15,8))
    fig.suptitle('with early stopping')
    keys=list(history.history.keys())
    ax[0].plot(history.epoch,history.history[keys[0]],label=keys[0])
    ax[0].plot(history.epoch,history.history[keys[2]],label=keys[2])
    ax[0].set_title('Accuracy')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend()

    ax[1].plot(history.epoch,history.history[keys[1]],label=keys[1])
    ax[1].plot(history.epoch,history.history[keys[3]],label=keys[2])
    ax[1].set_title('Loss')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()
    

    plt.show()
plot_graph(history)
